# %% [markdown]
# ---
# # **DATA PARSER and GRAPH CONSTRUCTION**
# using `PySpark` and `networkx`
#
# ---

# %%
# !pip install pyspark
# !pip install -U -q PyDrive
# !apt install openjdk-8-jdk-headless -qq
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.7/dist-packages (3.2.0)
# Requirement already satisfied: py4j==0.10.9.2 in /usr/local/lib/python3.7/dist-packages (from pyspark) (0.10.9.2)
# openjdk-8-jdk-headless is already the newest version (8u292-b10-0ubuntu1~18.04).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# LIBRARIES 

import pyspark
from pyspark.sql import *
from pyspark.sql.functions import *
from pyspark import SparkContext

import numpy as np
import networkx as nx
from google.colab import files

# %%
sc = SparkContext.getOrCreate()
sc.stop()

# Create the Spark Session
spark = SparkSession.builder.getOrCreate()
# Create the Spark Context
sc = spark.sparkContext

# %% [markdown]
# ### Upload the data and remove header
#
# Drop the selected CSV file to `Files` on the left to upload them to session storage.
#
# Write the selected CSV filename into the following cell.

# %%
filename = ""
lines = sc.textFile(filename)

header = lines.first()
lines = lines.filter(lambda line: line != header)

# %% [markdown]
# ---
# ---
#
# # **STEP 1**
#
# Step 1 is divided into the three blocks:
#
#
# > **Block 1:** bold text construction of `normalized_unique_pairs`
#
#
# > **Block 2:** construction of `basket_to_product`
#
#
# > Block 3: construction of `hh_to_basket`

# %% [markdown]
# ---
# ## **Block 1**
#
# Construction of RDD pipeline `normalized_unique_pairs` with all pairs with normalized weights
# : `(key: PRODUCT PAIR ---> value: WEIGHT)`
#
# > **Before:** lines of format as in original CSV:
# `household_key,BASKET_ID,DAY,PRODUCT_ID,QUANTITY,SALES_VALUE,STORE_ID,RETAIL_DISC,TRANS_TIME,WEEK_NO,
# COUPON_DISC,COUPON_MATCH_DISC`
#
# > **After:** lines of format `((product_ID_1, product_ID_2), normalized_weight)`

# %% [markdown]
# ### Helper functions
# #### for Block 1

# %%
def make_list(line):
  """
    Input: line of format as in original CSV
    Output: a pair formated as
            (basket_ID, product_ID)
  """
  splitted = line.split()
  lst = splitted[0].split(",")
  lst = list(map(lambda x: x, lst))

  BASKET_ID = int(lst[1])
  PRODUCT_ID = int(lst[3])

  return BASKET_ID, PRODUCT_ID


def generate_pairs_of_elements(line):
  """
    Input: line of RDD pipeline of format
            (basket_id, [prod_id_1, prod_id_2, ... prod_id_n])
    Output: pairs between all products in list [prod_id_1, prod_id_2, ... prod_id_n] with assigned weight:
                - pairs with distinct products get weight 1
                - self-loops get weight 0
             --> (((prod1_id, prod1_id), 0), ((prod1_id, prod2_id), 1), ..., ((prod1_id, prodn_id), 1), ((prod2_id, prod1_id), 1), ((prod2_id, prod2_id), 0), ...)
          
  """
  BASKET_ID = line[0]
  PRODUCTS_IDS = line[1]

  pairs = []

  if len(PRODUCTS_IDS) == 1:
    pairs.append(((PRODUCTS_IDS[0], PRODUCTS_IDS[0]), 0))
    return pairs
  else:
    for ID1 in PRODUCTS_IDS:
      pairs.append(((ID1, ID1), 0))
      for ID2 in PRODUCTS_IDS:
        if ID1 != ID2:
          pairs.append(((ID1, ID2), 1))

    return pairs

# %% [markdown]
# ### Execution cell
# #### for Block 1

# %%
basket_list = lines.map(make_list)
baskets_content = basket_list.groupByKey().mapValues(list)
generated_pairs = baskets_content.flatMap(generate_pairs_of_elements)
unique_pairs = generated_pairs.groupByKey().mapValues(list)
sum_unique_pairs = unique_pairs.map(lambda pair: (pair[0], np.sum(pair[1])))
sum_unique_pairs_correction = sum_unique_pairs.map(lambda pair: (pair[0], 1 if pair[1] == 0 else pair[1]))
W = sum_unique_pairs_correction.map(lambda line: line[1])
norm = W.max()
normalized_unique_pairs = sum_unique_pairs_correction.map(lambda pair: (pair[0], pair[1] / norm))

# %% [markdown]
# ---
# # **Block 2**
# Construction of RDD pipeline `basket_to_product` with all pairs
# `(key: BASKET (time_stamp) ---> value: PRODUCT pair)`
#
#
# > **Before:** lines of format as in original CSV:
# `household_key,BASKET_ID,DAY,PRODUCT_ID,QUANTITY,SALES_VALUE,STORE_ID,RETAIL_DISC,TRANS_TIME,WEEK_NO,
# COUPON_DISC,COUPON_MATCH_DISC`
#
#
#
#
# > **After:** lines of format `((basket_ID, (time_stamp)), (product_ID_1, product_ID_2))`

# %% [markdown]
# ### Helper functions
# #### for Block 2

# %%
def make_line_basket_product(line):
  """
    Input: line of format as in original CSV
    Output: ((basket_ID, (time_stamp)), product_ID)
  """
  splitted = line.split()
  lst = splitted[0].split(",")
  lst = list(map(lambda x: x, lst))

  HOUSEHOLD_KEY = int(lst[0])
  TIME_STAMP = (int(lst[9]), int(lst[2]), int(lst[8]))
  BASKET_ID = int(lst[1])
  PRODUCT_ID = int(lst[3])

  return (BASKET_ID, TIME_STAMP), PRODUCT_ID



def KEY_generate_pairs_of_elements(line):
  """
    Input: one line of RDD pipeline of format
            (basket_ID, (time_stamp)), product
    Output: key + pairs between all products:
             --> ((prod1_id, prod1_id), (prod1_id, prod2_id), ..., (prod1_id, prodn_id), (prod2_id, prod1_id), (prod2_id, prod2_id), ...)
  """
  KEY = line[0]
  PRODUCTS_IDS = line[1]

  pairs = []

  if len(PRODUCTS_IDS) == 1:
    pairs.append((PRODUCTS_IDS[0], PRODUCTS_IDS[0]))
    return ((KEY, pair) for pair in pairs)
  else:
    for ID1 in PRODUCTS_IDS:
      pairs.append((ID1, ID1))
      for ID2 in PRODUCTS_IDS:
        if ID1 != ID2:
          pairs.append((ID1, ID2))

  return ((KEY, pair) for pair in pairs)

# %% [markdown]
# ### Execution cell
# #### for Block 2

# %%
house_time_products_line = lines.map(make_line_basket_product)
grouped_basket = house_time_products_line.groupByKey().mapValues(list)
basket_to_product = grouped_basket.flatMap(KEY_generate_pairs_of_elements)

# %% [markdown]
# ---
# # **Block 3**
#
# Construction of RDD pipeline `hh_to_basket` with all pairs `(key: HOUSEHOLD ---> value: BASKET (time_stamp))`
#
#
# lines of format as in original CSV:
#
# > **Before:** lines of format as in original CSV:
# `household_key,BASKET_ID,DAY,PRODUCT_ID,QUANTITY,SALES_VALUE,STORE_ID,RETAIL_DISC,TRANS_TIME,WEEK_NO,
# COUPON_DISC,COUPON_MATCH_DISC`
#
# > **After:** lines of format `(HOUSEHOLD_KEY, (BASKET_ID, (time_stamp)))`

# %% [markdown]
# ### Helper functions
# #### for Block 3

# %%
def make_line_household_basket(line):
  """
    Input: line of format as in original CSV
    Output: (household_key, basket_id)
  """
  splitted = line.split()

  lst = splitted[0].split(",")
  lst = list(map(lambda x: x, lst))

  HOUSEHOLD_KEY = int(lst[0])
  BASKET_ID = int(lst[1])
  TIME_STAMP = (int(lst[9]), int(lst[2]), int(lst[8]))

  return HOUSEHOLD_KEY, (BASKET_ID, (TIME_STAMP))

# %% [markdown]
# ### Execution cell
# #### for Block 3

# %%
house_basket_line = lines.map(make_line_household_basket)
hh_to_basket = house_basket_line.groupByKey().flatMapValues(list).distinct()

# %% [markdown]
# ---
# ---
#
# # **STEP 2**

# %% [markdown]
# Construction of RDD pipeline `JOINED` with joining data from STEP 1: `(HOUSEHOLD ---> (BASKETS ---> PRODUCTS))`
#
#
#
# > **Before:** Three RDD pipelines from step 1:
# *   *Block 1:* `normalized_unique_pairs`:
# lines of format `((product_ID_1, product_ID_2), normalized_weight)`
# *   *Block 2:* `basket_to_product`:
# lines of format `((basket_ID, (time_stamp)), (product_ID_1, product_ID_2))`
# *   *Block 3:* `hh_to_basket`:
# lines of format `(HOUSEHOLD_KEY, (BASKET_ID, (time_stamp)))`
#
#
#
#
#
#
#
#
# > **After:** lines of format
# ```
# (HOUSEHOLD_KEY,
#     [(BASKET_ID_1, [all PRODUCT pairs of BASKET_ID_1 with normalized weight]),
#      (BASKET_ID_2, [all PRODUCT pairs of BASKET_ID_2 with normalized weight]),
#      ...
#      (BASKET_ID_n, [all PRODUCT pairs of BASKET_ID_n with normalized weight])
#     ]
# )
# ```

# %% [markdown]
# ### Helper functions
# #### for Step 2

# %%
def sort_baskets_time(line):
  key = line[0]
  return key, sorted(line[1], key = lambda x : x[0][0])

# %% [markdown]
# ### Execution cell
# #### for Spet 2
#
#
#
# > *Comment 1:* Baskets are sorted according to time stamp increasing
#
#
#
# > *Comment 2:* Only households with more than 5 purchases in the selected time period are considered

# %%
normalized = normalized_unique_pairs.map(lambda x: (x[0], x))
pairs_join_normalized = basket_to_product.map(lambda line: (line[1], line[0])).join(normalized).map(lambda line: line[1])
pairs_join_normalized_grouped = pairs_join_normalized.groupByKey().mapValues(list)
JOIN_ALL = hh_to_basket.map(lambda line: (line[1], line[0])).join(pairs_join_normalized_grouped).map(lambda line: (line[1][0], (line[0], line[1][1])))
JOINED = JOIN_ALL.groupByKey().mapValues(list).map(sort_baskets_time).filter(lambda line: len(line[1]) > 5)

# %% [markdown]
# ---
# ---
#
# # **STEP 3**
#
# Construction of RDD pipeline `GRAPHS_RDD` from data from STEP 2: `(HOUSEHOLD ---> list of networkx GRAPHS)`
#
#
#
# > **Before:** lines of format
# ```
# (HOUSEHOLD_KEY,
#     [(BASKET_ID_1, [all PRODUCT pairs of BASKET_ID_1 with normalized weight]),
#      (BASKET_ID_2, [all PRODUCT pairs of BASKET_ID_2 with normalized weight]),
#      ...
#      (BASKET_ID_n, [all PRODUCT pairs of BASKET_ID_n with normalized weight])
#     ]
# )
# ```
#
#
# > **After:** lines of format
# ```
# (HOUSEHOLD, [GRAPHS of class <networkx.classes.graph.Graph at 0x7f8c3752cbd0>])
# ```

# %% [markdown]
# ### Helper functions
# #### for Step 3

# %%
def make_prod_list(line):
  prods = []
  list_of_baskets = line[1] 
  for i in range(len(list_of_baskets)):
    list_of_prods = list_of_baskets[i][1]
    for j in range(len(list_of_prods)):
      prod1, prod2 = line[1][i][1][j][0]
      prods.append(prod1)
      prods.append(prod2)
  return line[0], prods


def make_graphs(prod_for_house):
  def make_graphs_(line):
    house_ID = line[0]
    # Every graph from one HH have the same nodes
    nodes = prod_for_house[house_ID]
    baskets_number = len(line[1])

    graphs = []
    # Construction of a graph for each basket
    for i in range(baskets_number):
      G = nx.Graph()
      G.add_nodes_from(nodes)
      basket_ID = line[1][i][0]
      products_number = len(line[1][i][1])

      for j in range(products_number):
        n1, n2 = line[1][i][1][j][0]
        W = line[1][i][1][j][1]
        G.add_edge(n1, n2, weight = W)

      graphs.append(G)

    return house_ID, graphs
  return make_graphs_

# %% [markdown]
# ### Execution cell
# #### for Step 3

# %%
products_for_house = JOINED.map(make_prod_list).collect()

prod_for_house = {}
for element in products_for_house:
  prod_for_house[element[0]] = element[1]

GRAPHS_RDD = JOINED.map(make_graphs(prod_for_house))

# %% [markdown]
# -----
# -----
#
# # STEP 4
#
# Collecting the generated graphs from STEP 3 and save them into the folder `Graphs`.

# %% [markdown]
# ### Exection cell
# #### for Step 4

# %%
GRAPHS = GRAPHS_RDD.collect()

# !mkdir Graphs
for element in GRAPHS:
  house_ID = element[0]
  list_of_graphs = element[1]
  for i, G in enumerate(list_of_graphs):
    nx.write_pajek(G, f"Graphs/{house_ID}_{i}.net")
# Out:
# mkdir: cannot create directory ‘Graphs’: File exists

# %% [markdown]
# Run the following cell to zip the graphs `Graphs_zip ` and download the zipped folder.

# %%
# !zip -r /content/Graphs_zip.zip /content/Graphs
files.download("/content/Graphs_zip.zip")
# Out:
# updating: content/Graphs/ (stored 0%)
# updating: content/Graphs/1096_1.net (deflated 73%)
# updating: content/Graphs/1351_1.net (deflated 72%)
# updating: content/Graphs/404_2.net (deflated 88%)
# updating: content/Graphs/1479_7.net (deflated 80%)
# updating: content/Graphs/884_10.net (deflated 72%)
# updating: content/Graphs/122_6.net (deflated 77%)
# updating: content/Graphs/924_0.net (deflated 85%)
# updating: content/Graphs/294_1.net (deflated 75%)
# updating: content/Graphs/1228_8.net (deflated 80%)
# updating: content/Graphs/1828_7.net (deflated 83%)
# updating: content/Graphs/575_1.net (deflated 84%)
# updating: content/Graphs/1916_3.net (deflated 73%)
# updating: content/Graphs/1369_2.net (deflated 75%)
# updating: content/Graphs/1569_1.net (deflated 68%)
# updating: content/Graphs/1828_13.net (deflated 76%)
# updating: content/Graphs/2110_5.net (deflated 76%)
# updating: content/Graphs/988_7.net (deflated 88%)
# updating: content/Graphs/1364_1.net (deflated 72%)
# updating: content/Graphs/1584_5.net (deflated 75%)
# updating: content/Graphs/2039_13.net (deflated 75%)
# updating: content/Graphs/2124_0.net (deflated 75%)
# updating: content/Graphs/918_9.net (deflated 75%)
# updating: content/Graphs/1943_3.net (deflated 77%)
# updating: content/Graphs/125_3.net (deflated 80%)
# updating: content/Graphs/1886_1.net (deflated 69%)
# updating: content/Graphs/1128_3.net (deflated 77%)
# updating: content/Graphs/1228_11.net (deflated 81%)
# updating: content/Graphs/2334_4.net (deflated 73%)
# updating: content/Graphs/2223_7.net (deflated 74%)
# updating: content/Graphs/1388_11.net (deflated 89%)
# updating: content/Graphs/2263_1.net (deflated 76%)
# updating: content/Graphs/474_1.net (deflated 74%)
# updating: content/Graphs/2371_0.net (deflated 79%)
# updating: content/Graphs/511_6.net (deflated 73%)
# updating: content/Graphs/427_2.net (deflated 81%)
# updating: content/Graphs/271_6.net (deflated 74%)
# updating: content/Graphs/1916_5.net (deflated 75%)
# updating: content/Graphs/718_2.net (deflated 78%)
# updating: content/Graphs/68_5.net (deflated 81%)
# updating: content/Graphs/2263_0.net (deflated 78%)
# updating: content/Graphs/2223_16.net (deflated 75%)
# updating: content/Graphs/314_2.net (deflated 78%)
# updating: content/Graphs/2305_4.net (deflated 85%)
# updating: content/Graphs/2223_5.net (deflated 74%)
# updating: content/Graphs/1479_8.net (deflated 70%)
# updating: content/Graphs/1886_5.net (deflated 73%)
# updating: content/Graphs/2009_8.net (deflated 81%)
# updating: content/Graphs/1612_4.net (deflated 69%)
# updating: content/Graphs/85_1.net (deflated 70%)
# updating: content/Graphs/1856_6.net (deflated 77%)
# updating: content/Graphs/2263_12.net (deflated 76%)
# updating: content/Graphs/364_0.net (deflated 83%)
# updating: content/Graphs/2223_6.net (deflated 74%)
# updating: content/Graphs/988_6.net (deflated 76%)
# updating: content/Graphs/2319_4.net (deflated 83%)
# updating: content/Graphs/2305_1.net (deflated 82%)
# updating: content/Graphs/2263_2.net (deflated 76%)
# updating: content/Graphs/1551_3.net (deflated 84%)
# updating: content/Graphs/294_4.net (deflated 81%)
# updating: content/Graphs/2263_35.net (deflated 76%)
# updating: content/Graphs/454_1.net (deflated 84%)
# updating: content/Graphs/1852_3.net (deflated 80%)
# updating: content/Graphs/1590_1.net (deflated 85%)
# updating: content/Graphs/1558_3.net (deflated 77%)
# updating: content/Graphs/1852_4.net (deflated 75%)
# updating: content/Graphs/1388_5.net (deflated 76%)
# updating: content/Graphs/122_3.net (deflated 76%)
# updating: content/Graphs/314_5.net (deflated 75%)
# updating: content/Graphs/1130_4.net (deflated 86%)
# updating: content/Graphs/1828_0.net (deflated 76%)
# updating: content/Graphs/304_2.net (deflated 78%)
# updating: content/Graphs/131_5.net (deflated 55%)
# updating: content/Graphs/364_5.net (deflated 76%)
# updating: content/Graphs/2223_19.net (deflated 73%)
# updating: content/Graphs/1745_4.net (deflated 80%)
# updating: content/Graphs/778_16.net (deflated 78%)
# updating: content/Graphs/271_1.net (deflated 73%)
# updating: content/Graphs/918_11.net (deflated 79%)
# updating: content/Graphs/2051_4.net (deflated 74%)
# updating: content/Graphs/718_22.net (deflated 76%)
# updating: content/Graphs/1364_6.net (deflated 72%)
# updating: content/Graphs/1284_5.net (deflated 74%)
# updating: content/Graphs/474_2.net (deflated 76%)
# updating: content/Graphs/1943_6.net (deflated 76%)
# updating: content/Graphs/2231_8.net (deflated 76%)
# updating: content/Graphs/2231_0.net (deflated 78%)
# updating: content/Graphs/1579_7.net (deflated 75%)
# updating: content/Graphs/2039_12.net (deflated 76%)
# updating: content/Graphs/454_6.net (deflated 77%)
# updating: content/Graphs/918_8.net (deflated 76%)
# updating: content/Graphs/314_1.net (deflated 76%)
# updating: content/Graphs/988_13.net (deflated 76%)
# updating: content/Graphs/365_7.net (deflated 75%)
# updating: content/Graphs/1096_5.net (deflated 77%)
# updating: content/Graphs/1917_3.net (deflated 76%)
# updating: content/Graphs/1241_7.net (deflated 73%)
# updating: content/Graphs/1549_2.net (deflated 75%)
# updating: content/Graphs/2223_1.net (deflated 74%)
# updating: content/Graphs/718_8.net (deflated 83%)
# updating: content/Graphs/2448_6.net (deflated 77%)
# updating: content/Graphs/1241_5.net (deflated 73%)
# updating: content/Graphs/2319_0.net (deflated 76%)
# updating: content/Graphs/1163_0.net (deflated 88%)
# updating: content/Graphs/454_4.net (deflated 77%)
# updating: content/Graphs/1828_2.net (deflated 77%)
# updating: content/Graphs/778_2.net (deflated 76%)
# updating: content/Graphs/381_1.net (deflated 76%)
# updating: content/Graphs/2263_8.net (deflated 76%)
# updating: content/Graphs/718_9.net (deflated 81%)
# updating: content/Graphs/427_1.net (deflated 72%)
# updating: content/Graphs/2231_6.net (deflated 80%)
# updating: content/Graphs/2223_4.net (deflated 76%)
# updating: content/Graphs/1617_3.net (deflated 75%)
# updating: content/Graphs/2334_5.net (deflated 72%)
# updating: content/Graphs/1284_2.net (deflated 75%)
# updating: content/Graphs/1612_1.net (deflated 71%)
# updating: content/Graphs/575_0.net (deflated 74%)
# updating: content/Graphs/918_7.net (deflated 79%)
# updating: content/Graphs/1551_5.net (deflated 76%)
# updating: content/Graphs/1138_2.net (deflated 73%)
# updating: content/Graphs/1128_0.net (deflated 75%)
# updating: content/Graphs/2051_16.net (deflated 73%)
# updating: content/Graphs/2305_2.net (deflated 75%)
# updating: content/Graphs/1745_1.net (deflated 74%)
# updating: content/Graphs/2305_0.net (deflated 87%)
# updating: content/Graphs/1905_0.net (deflated 85%)
# updating: content/Graphs/1704_3.net (deflated 72%)
# updating: content/Graphs/364_1.net (deflated 72%)
# updating: content/Graphs/1163_2.net (deflated 75%)
# updating: content/Graphs/2051_15.net (deflated 73%)
# updating: content/Graphs/1284_3.net (deflated 74%)
# updating: content/Graphs/2263_17.net (deflated 76%)
# updating: content/Graphs/718_4.net (deflated 82%)
# updating: content/Graphs/1260_12.net (deflated 88%)
# updating: content/Graphs/511_1.net (deflated 73%)
# updating: content/Graphs/2018_4.net (deflated 74%)
# updating: content/Graphs/432_4.net (deflated 75%)
# updating: content/Graphs/2263_21.net (deflated 78%)
# updating: content/Graphs/947_1.net (deflated 79%)
# updating: content/Graphs/918_12.net (deflated 77%)
# updating: content/Graphs/1351_0.net (deflated 65%)
# updating: content/Graphs/314_6.net (deflated 76%)
# updating: content/Graphs/85_4.net (deflated 69%)
# updating: content/Graphs/2018_5.net (deflated 77%)
# updating: content/Graphs/2018_0.net (deflated 87%)
# updating: content/Graphs/1558_8.net (deflated 82%)
# updating: content/Graphs/2110_11.net (deflated 86%)
# updating: content/Graphs/1803_1.net (deflated 81%)
# updating: content/Graphs/2231_3.net (deflated 75%)
# updating: content/Graphs/1917_10.net (deflated 79%)
# updating: content/Graphs/1917_7.net (deflated 75%)
# updating: content/Graphs/432_0.net (deflated 71%)
# updating: content/Graphs/2193_6.net (deflated 86%)
# updating: content/Graphs/294_0.net (deflated 75%)
# updating: content/Graphs/1590_4.net (deflated 81%)
# updating: content/Graphs/1479_4.net (deflated 73%)
# updating: content/Graphs/679_5.net (deflated 89%)
# updating: content/Graphs/381_4.net (deflated 77%)
# updating: content/Graphs/1388_12.net (deflated 76%)
# updating: content/Graphs/2051_10.net (deflated 82%)
# updating: content/Graphs/1549_5.net (deflated 82%)
# updating: content/Graphs/1479_0.net (deflated 74%)
# updating: content/Graphs/1289_1.net (deflated 78%)
# updating: content/Graphs/2051_8.net (deflated 73%)
# updating: content/Graphs/1852_1.net (deflated 84%)
# updating: content/Graphs/698_4.net (deflated 72%)
# updating: content/Graphs/2110_10.net (deflated 85%)
# updating: content/Graphs/1569_4.net (deflated 71%)
# updating: content/Graphs/1617_5.net (deflated 87%)
# updating: content/Graphs/2110_12.net (deflated 77%)
# updating: content/Graphs/427_3.net (deflated 72%)
# updating: content/Graphs/2371_3.net (deflated 80%)
# updating: content/Graphs/2110_1.net (deflated 87%)
# updating: content/Graphs/1289_0.net (deflated 65%)
# updating: content/Graphs/293_1.net (deflated 88%)
# updating: content/Graphs/1707_8.net (deflated 71%)
# updating: content/Graphs/918_0.net (deflated 75%)
# updating: content/Graphs/1287_3.net (deflated 81%)
# updating: content/Graphs/884_7.net (deflated 74%)
# updating: content/Graphs/131_2.net (deflated 55%)
# updating: content/Graphs/988_9.net (deflated 77%)
# updating: content/Graphs/2263_34.net (deflated 76%)
# updating: content/Graphs/718_16.net (deflated 77%)
# updating: content/Graphs/1943_4.net (deflated 88%)
# updating: content/Graphs/1809_1.net (deflated 74%)
# updating: content/Graphs/1128_2.net (deflated 71%)
# updating: content/Graphs/2334_6.net (deflated 72%)
# updating: content/Graphs/718_5.net (deflated 79%)
# updating: content/Graphs/1260_1.net (deflated 84%)
# updating: content/Graphs/698_9.net (deflated 75%)
# updating: content/Graphs/947_6.net (deflated 82%)
# updating: content/Graphs/223_2.net (deflated 74%)
# updating: content/Graphs/698_0.net (deflated 78%)
# updating: content/Graphs/2263_6.net (deflated 77%)
# updating: content/Graphs/1886_6.net (deflated 71%)
# updating: content/Graphs/1426_0.net (deflated 82%)
# updating: content/Graphs/1818_1.net (deflated 88%)
# updating: content/Graphs/2305_9.net (deflated 86%)
# updating: content/Graphs/314_7.net (deflated 76%)
# updating: content/Graphs/2009_3.net (deflated 84%)
# updating: content/Graphs/1228_19.net (deflated 75%)
# updating: content/Graphs/2371_1.net (deflated 81%)
# updating: content/Graphs/2208_2.net (deflated 79%)
# updating: content/Graphs/718_14.net (deflated 79%)
# updating: content/Graphs/183_5.net (deflated 75%)
# updating: content/Graphs/1835_9.net (deflated 75%)
# updating: content/Graphs/314_4.net (deflated 75%)
# updating: content/Graphs/122_18.net (deflated 76%)
# updating: content/Graphs/1835_11.net (deflated 79%)
# updating: content/Graphs/1704_11.net (deflated 72%)
# updating: content/Graphs/2263_15.net (deflated 76%)
# updating: content/Graphs/2263_42.net (deflated 76%)
# updating: content/Graphs/122_14.net (deflated 75%)
# updating: content/Graphs/918_10.net (deflated 75%)
# updating: content/Graphs/884_12.net (deflated 74%)
# updating: content/Graphs/2223_2.net (deflated 73%)
# updating: content/Graphs/381_3.net (deflated 76%)
# updating: content/Graphs/932_6.net (deflated 87%)
# updating: content/Graphs/122_10.net (deflated 75%)
# updating: content/Graphs/718_11.net (deflated 76%)
# updating: content/Graphs/718_12.net (deflated 83%)
# updating: content/Graphs/988_1.net (deflated 76%)
# updating: content/Graphs/1803_4.net (deflated 86%)
# updating: content/Graphs/427_5.net (deflated 81%)
# updating: content/Graphs/2009_9.net (deflated 76%)
# updating: content/Graphs/2263_33.net (deflated 77%)
# updating: content/Graphs/1551_1.net (deflated 75%)
# updating: content/Graphs/404_6.net (deflated 76%)
# updating: content/Graphs/183_6.net (deflated 75%)
# updating: content/Graphs/1905_6.net (deflated 75%)
# updating: content/Graphs/451_2.net (deflated 74%)
# updating: content/Graphs/364_3.net (deflated 77%)
# updating: content/Graphs/480_0.net (deflated 75%)
# updating: content/Graphs/2263_37.net (deflated 76%)
# updating: content/Graphs/1917_0.net (deflated 82%)
# updating: content/Graphs/365_1.net (deflated 87%)
# updating: content/Graphs/778_5.net (deflated 77%)
# updating: content/Graphs/2039_4.net (deflated 76%)
# updating: content/Graphs/2427_0.net (deflated 86%)
# updating: content/Graphs/271_8.net (deflated 81%)
# updating: content/Graphs/1260_10.net (deflated 76%)
# updating: content/Graphs/131_1.net (deflated 61%)
# updating: content/Graphs/1426_1.net (deflated 75%)
# updating: content/Graphs/1707_4.net (deflated 71%)
# updating: content/Graphs/314_8.net (deflated 88%)
# updating: content/Graphs/2051_11.net (deflated 73%)
# updating: content/Graphs/1479_9.net (deflated 73%)
# updating: content/Graphs/365_0.net (deflated 76%)
# updating: content/Graphs/988_8.net (deflated 76%)
# updating: content/Graphs/1828_8.net (deflated 76%)
# updating: content/Graphs/718_15.net (deflated 76%)
# updating: content/Graphs/253_4.net (deflated 75%)
# updating: content/Graphs/122_12.net (deflated 75%)
# updating: content/Graphs/988_12.net (deflated 76%)
# updating: content/Graphs/1584_3.net (deflated 75%)
# updating: content/Graphs/1351_5.net (deflated 74%)
# updating: content/Graphs/1287_0.net (deflated 74%)
# updating: content/Graphs/93_5.net (deflated 88%)
# updating: content/Graphs/1617_4.net (deflated 74%)
# updating: content/Graphs/698_8.net (deflated 73%)
# updating: content/Graphs/125_5.net (deflated 79%)
# updating: content/Graphs/404_4.net (deflated 76%)
# updating: content/Graphs/2231_10.net (deflated 78%)
# updating: content/Graphs/1704_9.net (deflated 73%)
# updating: content/Graphs/1579_5.net (deflated 75%)
# updating: content/Graphs/1096_9.net (deflated 72%)
# updating: content/Graphs/93_0.net (deflated 82%)
# updating: content/Graphs/1852_7.net (deflated 85%)
# updating: content/Graphs/1130_3.net (deflated 75%)
# updating: content/Graphs/2371_6.net (deflated 77%)
# updating: content/Graphs/480_7.net (deflated 86%)
# updating: content/Graphs/1551_2.net (deflated 79%)
# updating: content/Graphs/474_6.net (deflated 81%)
# updating: content/Graphs/1228_20.net (deflated 81%)
# updating: content/Graphs/947_3.net (deflated 77%)
# updating: content/Graphs/1228_2.net (deflated 74%)
# updating: content/Graphs/1289_6.net (deflated 65%)
# updating: content/Graphs/2223_25.net (deflated 73%)
# updating: content/Graphs/1490_1.net (deflated 77%)
# updating: content/Graphs/2223_21.net (deflated 73%)
# updating: content/Graphs/2185_0.net (deflated 88%)
# updating: content/Graphs/778_1.net (deflated 83%)
# updating: content/Graphs/1917_9.net (deflated 79%)
# updating: content/Graphs/1096_13.net (deflated 72%)
# updating: content/Graphs/2110_4.net (deflated 85%)
# updating: content/Graphs/1835_14.net (deflated 77%)
# updating: content/Graphs/2051_17.net (deflated 76%)
# updating: content/Graphs/1228_10.net (deflated 74%)
# updating: content/Graphs/2009_2.net (deflated 89%)
# updating: content/Graphs/2305_6.net (deflated 77%)
# updating: content/Graphs/253_2.net (deflated 84%)
# updating: content/Graphs/2051_0.net (deflated 74%)
# updating: content/Graphs/1886_4.net (deflated 73%)
# updating: content/Graphs/1803_3.net (deflated 76%)
# updating: content/Graphs/2448_3.net (deflated 88%)
# updating: content/Graphs/2009_5.net (deflated 76%)
# updating: content/Graphs/293_5.net (deflated 76%)
# updating: content/Graphs/2334_0.net (deflated 87%)
# updating: content/Graphs/1369_0.net (deflated 86%)
# updating: content/Graphs/293_0.net (deflated 76%)
# updating: content/Graphs/93_4.net (deflated 77%)
# updating: content/Graphs/51_6.net (deflated 75%)
# updating: content/Graphs/125_7.net (deflated 80%)
# updating: content/Graphs/2051_5.net (deflated 77%)
# updating: content/Graphs/68_6.net (deflated 69%)
# updating: content/Graphs/1856_4.net (deflated 73%)
# updating: content/Graphs/125_10.net (deflated 79%)
# updating: content/Graphs/1138_1.net (deflated 79%)
# updating: content/Graphs/98_4.net (deflated 73%)
# updating: content/Graphs/1228_12.net (deflated 74%)
# updating: content/Graphs/718_7.net (deflated 76%)
# updating: content/Graphs/511_5.net (deflated 78%)
# updating: content/Graphs/271_2.net (deflated 73%)
# updating: content/Graphs/918_2.net (deflated 86%)
# updating: content/Graphs/1241_6.net (deflated 74%)
# updating: content/Graphs/1241_3.net (deflated 73%)
# updating: content/Graphs/122_22.net (deflated 76%)
# updating: content/Graphs/183_4.net (deflated 75%)
# updating: content/Graphs/1612_2.net (deflated 69%)
# updating: content/Graphs/1835_13.net (deflated 79%)
# updating: content/Graphs/1172_5.net (deflated 81%)
# updating: content/Graphs/404_7.net (deflated 79%)
# updating: content/Graphs/1590_5.net (deflated 85%)
# updating: content/Graphs/1284_4.net (deflated 81%)
# updating: content/Graphs/454_0.net (deflated 86%)
# updating: content/Graphs/271_7.net (deflated 73%)
# updating: content/Graphs/1707_11.net (deflated 71%)
# updating: content/Graphs/778_8.net (deflated 75%)
# updating: content/Graphs/271_3.net (deflated 78%)
# updating: content/Graphs/1579_2.net (deflated 83%)
# updating: content/Graphs/1835_0.net (deflated 87%)
# updating: content/Graphs/778_20.net (deflated 75%)
# updating: content/Graphs/1856_3.net (deflated 73%)
# updating: content/Graphs/947_0.net (deflated 79%)
# updating: content/Graphs/1241_9.net (deflated 82%)
# updating: content/Graphs/183_2.net (deflated 88%)
# updating: content/Graphs/932_1.net (deflated 72%)
# updating: content/Graphs/432_2.net (deflated 68%)
# updating: content/Graphs/1856_2.net (deflated 75%)
# updating: content/Graphs/1584_0.net (deflated 83%)
# updating: content/Graphs/1284_0.net (deflated 74%)
# updating: content/Graphs/2231_9.net (deflated 76%)
# updating: content/Graphs/2263_24.net (deflated 76%)
# updating: content/Graphs/1364_4.net (deflated 80%)
# updating: content/Graphs/1943_2.net (deflated 83%)
# updating: content/Graphs/1828_10.net (deflated 77%)
# updating: content/Graphs/2223_24.net (deflated 73%)
# updating: content/Graphs/1803_5.net (deflated 76%)
# updating: content/Graphs/1856_7.net (deflated 82%)
# updating: content/Graphs/1590_3.net (deflated 77%)
# updating: content/Graphs/1917_13.net (deflated 76%)
# updating: content/Graphs/1704_12.net (deflated 72%)
# updating: content/Graphs/1704_7.net (deflated 73%)
# updating: content/Graphs/1828_3.net (deflated 87%)
# updating: content/Graphs/1260_2.net (deflated 83%)
# updating: content/Graphs/1943_1.net (deflated 75%)
# updating: content/Graphs/480_8.net (deflated 86%)
# updating: content/Graphs/114_1.net (deflated 77%)
# updating: content/Graphs/2319_2.net (deflated 77%)
# updating: content/Graphs/2185_3.net (deflated 78%)
# updating: content/Graphs/1704_8.net (deflated 73%)
# updating: content/Graphs/183_3.net (deflated 75%)
# updating: content/Graphs/2231_4.net (deflated 76%)
# updating: content/Graphs/718_0.net (deflated 88%)
# updating: content/Graphs/1096_2.net (deflated 72%)
# updating: content/Graphs/51_5.net (deflated 81%)
# updating: content/Graphs/1707_9.net (deflated 71%)
# updating: content/Graphs/2263_13.net (deflated 81%)
# updating: content/Graphs/1818_3.net (deflated 80%)
# updating: content/Graphs/1096_7.net (deflated 74%)
# updating: content/Graphs/718_13.net (deflated 81%)
# updating: content/Graphs/223_5.net (deflated 70%)
# updating: content/Graphs/1558_7.net (deflated 76%)
# updating: content/Graphs/932_5.net (deflated 83%)
# updating: content/Graphs/454_5.net (deflated 77%)
# updating: content/Graphs/1584_6.net (deflated 72%)
# updating: content/Graphs/718_3.net (deflated 81%)
# updating: content/Graphs/947_4.net (deflated 80%)
# updating: content/Graphs/2193_7.net (deflated 79%)
# updating: content/Graphs/183_0.net (deflated 83%)
# updating: content/Graphs/2193_0.net (deflated 76%)
# updating: content/Graphs/2448_5.net (deflated 84%)
# updating: content/Graphs/474_3.net (deflated 87%)
# updating: content/Graphs/1579_6.net (deflated 75%)
# updating: content/Graphs/2319_5.net (deflated 75%)
# updating: content/Graphs/122_20.net (deflated 75%)
# updating: content/Graphs/698_1.net (deflated 80%)
# updating: content/Graphs/451_1.net (deflated 80%)
# updating: content/Graphs/1878_0.net (deflated 76%)
# updating: content/Graphs/1228_16.net (deflated 74%)
# updating: content/Graphs/1579_1.net (deflated 74%)
# updating: content/Graphs/2193_9.net (deflated 87%)
# updating: content/Graphs/122_7.net (deflated 84%)
# updating: content/Graphs/1096_0.net (deflated 75%)
# updating: content/Graphs/1369_4.net (deflated 78%)
# updating: content/Graphs/361_4.net (deflated 76%)
# updating: content/Graphs/474_5.net (deflated 87%)
# updating: content/Graphs/2448_1.net (deflated 75%)
# updating: content/Graphs/1878_3.net (deflated 76%)
# updating: content/Graphs/1549_3.net (deflated 76%)
# updating: content/Graphs/805_8.net (deflated 78%)
# updating: content/Graphs/1809_4.net (deflated 76%)
# updating: content/Graphs/1818_5.net (deflated 80%)
# updating: content/Graphs/2263_29.net (deflated 76%)
# updating: content/Graphs/884_6.net (deflated 72%)
# updating: content/Graphs/1163_3.net (deflated 77%)
# updating: content/Graphs/1745_0.net (deflated 87%)
# updating: content/Graphs/2051_14.net (deflated 73%)
# updating: content/Graphs/1856_0.net (deflated 76%)
# updating: content/Graphs/1128_1.net (deflated 71%)
# updating: content/Graphs/381_2.net (deflated 80%)
# updating: content/Graphs/2009_4.net (deflated 82%)
# updating: content/Graphs/122_8.net (deflated 75%)
# updating: content/Graphs/293_6.net (deflated 76%)
# updating: content/Graphs/1704_1.net (deflated 72%)
# updating: content/Graphs/1228_15.net (deflated 75%)
# updating: content/Graphs/1287_5.net (deflated 78%)
# updating: content/Graphs/2185_5.net (deflated 86%)
# updating: content/Graphs/1809_3.net (deflated 76%)
# updating: content/Graphs/2319_1.net (deflated 75%)
# updating: content/Graphs/1579_0.net (deflated 75%)
# updating: content/Graphs/2223_3.net (deflated 74%)
# updating: content/Graphs/1617_1.net (deflated 74%)
# updating: content/Graphs/2051_1.net (deflated 74%)
# updating: content/Graphs/1228_13.net (deflated 81%)
# updating: content/Graphs/2193_8.net (deflated 76%)
# updating: content/Graphs/1260_4.net (deflated 76%)
# updating: content/Graphs/1917_1.net (deflated 75%)
# updating: content/Graphs/1617_2.net (deflated 86%)
# updating: content/Graphs/1612_0.net (deflated 84%)
# updating: content/Graphs/361_10.net (deflated 78%)
# updating: content/Graphs/2263_20.net (deflated 76%)
# updating: content/Graphs/1287_1.net (deflated 77%)
# updating: content/Graphs/77_2.net (deflated 88%)
# updating: content/Graphs/778_4.net (deflated 87%)
# updating: content/Graphs/1096_15.net (deflated 77%)
# updating: content/Graphs/1241_1.net (deflated 79%)
# updating: content/Graphs/1228_1.net (deflated 77%)
# updating: content/Graphs/1490_6.net (deflated 75%)
# updating: content/Graphs/294_7.net (deflated 84%)
# updating: content/Graphs/98_1.net (deflated 74%)
# updating: content/Graphs/2427_3.net (deflated 84%)
# updating: content/Graphs/2305_8.net (deflated 76%)
# updating: content/Graphs/679_2.net (deflated 76%)
# updating: content/Graphs/2208_0.net (deflated 85%)
# updating: content/Graphs/884_11.net (deflated 73%)
# updating: content/Graphs/223_3.net (deflated 80%)
# updating: content/Graphs/1943_0.net (deflated 75%)
# updating: content/Graphs/1260_8.net (deflated 77%)
# updating: content/Graphs/1590_0.net (deflated 83%)
# updating: content/Graphs/1886_7.net (deflated 74%)
# updating: content/Graphs/1809_5.net (deflated 79%)
# updating: content/Graphs/1878_1.net (deflated 86%)
# updating: content/Graphs/1172_4.net (deflated 71%)
# updating: content/Graphs/884_9.net (deflated 81%)
# updating: content/Graphs/1096_11.net (deflated 72%)
# updating: content/Graphs/1612_5.net (deflated 69%)
# updating: content/Graphs/1835_5.net (deflated 75%)
# updating: content/Graphs/125_0.net (deflated 78%)
# updating: content/Graphs/1130_2.net (deflated 79%)
# updating: content/Graphs/1916_1.net (deflated 77%)
# updating: content/Graphs/778_3.net (deflated 76%)
# updating: content/Graphs/805_2.net (deflated 75%)
# updating: content/Graphs/988_11.net (deflated 83%)
# updating: content/Graphs/122_15.net (deflated 79%)
# updating: content/Graphs/404_8.net (deflated 82%)
# updating: content/Graphs/884_1.net (deflated 73%)
# updating: content/Graphs/1284_6.net (deflated 87%)
# updating: content/Graphs/98_5.net (deflated 76%)
# updating: content/Graphs/932_2.net (deflated 72%)
# updating: content/Graphs/114_2.net (deflated 84%)
# updating: content/Graphs/304_5.net (deflated 75%)
# updating: content/Graphs/778_13.net (deflated 76%)
# updating: content/Graphs/2185_4.net (deflated 79%)
# updating: content/Graphs/365_3.net (deflated 74%)
# updating: content/Graphs/1364_3.net (deflated 73%)
# updating: content/Graphs/988_2.net (deflated 84%)
# updating: content/Graphs/1905_10.net (deflated 79%)
# updating: content/Graphs/2039_0.net (deflated 79%)
# updating: content/Graphs/2110_0.net (deflated 81%)
# updating: content/Graphs/1612_3.net (deflated 75%)
# updating: content/Graphs/2263_23.net (deflated 77%)
# updating: content/Graphs/51_4.net (deflated 75%)
# updating: content/Graphs/2263_7.net (deflated 76%)
# updating: content/Graphs/2319_7.net (deflated 72%)
# updating: content/Graphs/2448_0.net (deflated 79%)
# updating: content/Graphs/511_0.net (deflated 79%)
# updating: content/Graphs/918_1.net (deflated 80%)
# updating: content/Graphs/2193_2.net (deflated 84%)
# updating: content/Graphs/2263_44.net (deflated 76%)
# updating: content/Graphs/2009_7.net (deflated 78%)
# updating: content/Graphs/1138_3.net (deflated 87%)
# updating: content/Graphs/223_0.net (deflated 72%)
# updating: content/Graphs/511_7.net (deflated 77%)
# updating: content/Graphs/1835_10.net (deflated 76%)
# updating: content/Graphs/1426_3.net (deflated 83%)
# updating: content/Graphs/125_4.net (deflated 81%)
# updating: content/Graphs/1916_2.net (deflated 76%)
# updating: content/Graphs/575_5.net (deflated 83%)
# updating: content/Graphs/1490_4.net (deflated 79%)
# updating: content/Graphs/2263_28.net (deflated 76%)
# updating: content/Graphs/988_5.net (deflated 76%)
# updating: content/Graphs/2263_9.net (deflated 77%)
# updating: content/Graphs/480_1.net (deflated 75%)
# updating: content/Graphs/480_2.net (deflated 84%)
# updating: content/Graphs/1852_8.net (deflated 76%)
# updating: content/Graphs/947_2.net (deflated 76%)
# updating: content/Graphs/1364_0.net (deflated 76%)
# updating: content/Graphs/1228_9.net (deflated 74%)
# updating: content/Graphs/778_14.net (deflated 80%)
# updating: content/Graphs/2039_2.net (deflated 75%)
# updating: content/Graphs/698_6.net (deflated 76%)
# updating: content/Graphs/1828_6.net (deflated 82%)
# updating: content/Graphs/122_9.net (deflated 75%)
# updating: content/Graphs/947_7.net (deflated 73%)
# updating: content/Graphs/1388_8.net (deflated 78%)
# updating: content/Graphs/2039_14.net (deflated 80%)
# updating: content/Graphs/1163_4.net (deflated 85%)
# updating: content/Graphs/2319_6.net (deflated 77%)
# updating: content/Graphs/1287_6.net (deflated 82%)
# updating: content/Graphs/2263_4.net (deflated 76%)
# updating: content/Graphs/68_1.net (deflated 69%)
# updating: content/Graphs/1707_3.net (deflated 88%)
# updating: content/Graphs/778_10.net (deflated 76%)
# updating: content/Graphs/698_3.net (deflated 73%)
# updating: content/Graphs/432_5.net (deflated 74%)
# updating: content/Graphs/1228_0.net (deflated 74%)
# updating: content/Graphs/2263_36.net (deflated 76%)
# updating: content/Graphs/884_0.net (deflated 74%)
# updating: content/Graphs/1388_7.net (deflated 76%)
# updating: content/Graphs/1241_8.net (deflated 74%)
# updating: content/Graphs/1128_7.net (deflated 72%)
# updating: content/Graphs/364_2.net (deflated 71%)
# updating: content/Graphs/2208_5.net (deflated 77%)
# updating: content/Graphs/1745_5.net (deflated 73%)
# updating: content/Graphs/1388_13.net (deflated 78%)
# updating: content/Graphs/988_0.net (deflated 88%)
# updating: content/Graphs/1228_4.net (deflated 74%)
# updating: content/Graphs/679_4.net (deflated 75%)
# updating: content/Graphs/1828_4.net (deflated 86%)
# updating: content/Graphs/2223_17.net (deflated 73%)
# updating: content/Graphs/2039_3.net (deflated 82%)
# updating: content/Graphs/2263_39.net (deflated 84%)
# updating: content/Graphs/1917_6.net (deflated 76%)
# updating: content/Graphs/2427_6.net (deflated 77%)
# updating: content/Graphs/1579_10.net (deflated 74%)
# updating: content/Graphs/364_6.net (deflated 82%)
# updating: content/Graphs/575_2.net (deflated 83%)
# updating: content/Graphs/2263_11.net (deflated 76%)
# updating: content/Graphs/1569_2.net (deflated 67%)
# updating: content/Graphs/2263_3.net (deflated 76%)
# updating: content/Graphs/1287_2.net (deflated 83%)
# updating: content/Graphs/125_6.net (deflated 80%)
# updating: content/Graphs/778_9.net (deflated 75%)
# updating: content/Graphs/314_3.net (deflated 78%)
# updating: content/Graphs/2231_11.net (deflated 83%)
# updating: content/Graphs/1886_3.net (deflated 70%)
# updating: content/Graphs/122_17.net (deflated 79%)
# updating: content/Graphs/125_1.net (deflated 78%)
# updating: content/Graphs/2334_3.net (deflated 72%)
# updating: content/Graphs/718_21.net (deflated 79%)
# updating: content/Graphs/778_15.net (deflated 75%)
# updating: content/Graphs/1289_4.net (deflated 68%)
# updating: content/Graphs/1803_2.net (deflated 75%)
# updating: content/Graphs/1096_4.net (deflated 73%)
# updating: content/Graphs/2263_10.net (deflated 76%)
# updating: content/Graphs/2223_23.net (deflated 73%)
# updating: content/Graphs/1096_3.net (deflated 82%)
# updating: content/Graphs/2263_41.net (deflated 76%)
# updating: content/Graphs/1096_14.net (deflated 73%)
# updating: content/Graphs/98_3.net (deflated 79%)
# updating: content/Graphs/2223_15.net (deflated 74%)
# updating: content/Graphs/1905_4.net (deflated 75%)
# updating: content/Graphs/1228_3.net (deflated 75%)
# updating: content/Graphs/427_0.net (deflated 80%)
# updating: content/Graphs/1852_6.net (deflated 84%)
# updating: content/Graphs/1584_4.net (deflated 72%)
# updating: content/Graphs/1917_2.net (deflated 80%)
# updating: content/Graphs/805_5.net (deflated 74%)
# updating: content/Graphs/778_17.net (deflated 75%)
# updating: content/Graphs/1351_2.net (deflated 69%)
# updating: content/Graphs/884_2.net (deflated 79%)
# updating: content/Graphs/114_3.net (deflated 79%)
# updating: content/Graphs/2448_4.net (deflated 87%)
# updating: content/Graphs/2223_18.net (deflated 73%)
# updating: content/Graphs/1704_10.net (deflated 74%)
# updating: content/Graphs/1558_5.net (deflated 77%)
# updating: content/Graphs/122_2.net (deflated 78%)
# updating: content/Graphs/1260_7.net (deflated 81%)
# updating: content/Graphs/1163_1.net (deflated 78%)
# updating: content/Graphs/361_0.net (deflated 84%)
# updating: content/Graphs/2223_14.net (deflated 74%)
# updating: content/Graphs/223_1.net (deflated 70%)
# updating: content/Graphs/1835_2.net (deflated 82%)
# updating: content/Graphs/1128_10.net (deflated 71%)
# updating: content/Graphs/2305_7.net (deflated 76%)
# updating: content/Graphs/1228_18.net (deflated 74%)
# updating: content/Graphs/1549_0.net (deflated 78%)
# updating: content/Graphs/1835_1.net (deflated 81%)
# updating: content/Graphs/2110_9.net (deflated 82%)
# updating: content/Graphs/1388_2.net (deflated 76%)
# updating: content/Graphs/1878_8.net (deflated 73%)
# updating: content/Graphs/2223_11.net (deflated 74%)
# updating: content/Graphs/1558_4.net (deflated 81%)
# updating: content/Graphs/77_3.net (deflated 87%)
# updating: content/Graphs/1886_0.net (deflated 71%)
# updating: content/Graphs/271_9.net (deflated 73%)
# updating: content/Graphs/1138_4.net (deflated 79%)
# updating: content/Graphs/1479_10.net (deflated 70%)
# updating: content/Graphs/293_3.net (deflated 83%)
# updating: content/Graphs/131_3.net (deflated 55%)
# updating: content/Graphs/2039_1.net (deflated 87%)
# updating: content/Graphs/432_6.net (deflated 69%)
# updating: content/Graphs/1818_6.net (deflated 77%)
# updating: content/Graphs/1943_7.net (deflated 78%)
# updating: content/Graphs/2009_0.net (deflated 76%)
# updating: content/Graphs/1878_4.net (deflated 76%)
# updating: content/Graphs/778_11.net (deflated 75%)
# updating: content/Graphs/1138_0.net (deflated 74%)
# updating: content/Graphs/2263_45.net (deflated 76%)
# updating: content/Graphs/2223_12.net (deflated 76%)
# updating: content/Graphs/1584_2.net (deflated 73%)
# updating: content/Graphs/122_0.net (deflated 75%)
# updating: content/Graphs/1835_4.net (deflated 77%)
# updating: content/Graphs/85_0.net (deflated 70%)
# updating: content/Graphs/2110_8.net (deflated 77%)
# updating: content/Graphs/932_0.net (deflated 72%)
# updating: content/Graphs/51_2.net (deflated 74%)
# updating: content/Graphs/1569_3.net (deflated 70%)
# updating: content/Graphs/1704_2.net (deflated 74%)
# updating: content/Graphs/2193_3.net (deflated 86%)
# updating: content/Graphs/51_0.net (deflated 81%)
# updating: content/Graphs/1818_4.net (deflated 76%)
# updating: content/Graphs/1228_14.net (deflated 75%)
# updating: content/Graphs/1369_5.net (deflated 74%)
# updating: content/Graphs/1579_4.net (deflated 74%)
# updating: content/Graphs/2039_7.net (deflated 81%)
# updating: content/Graphs/253_3.net (deflated 81%)
# updating: content/Graphs/884_13.net (deflated 72%)
# updating: content/Graphs/1096_17.net (deflated 72%)
# updating: content/Graphs/924_5.net (deflated 84%)
# updating: content/Graphs/679_8.net (deflated 77%)
# updating: content/Graphs/404_0.net (deflated 82%)
# updating: content/Graphs/2263_25.net (deflated 76%)
# updating: content/Graphs/2124_4.net (deflated 87%)
# updating: content/Graphs/718_19.net (deflated 80%)
# updating: content/Graphs/1617_0.net (deflated 74%)
# updating: content/Graphs/2039_5.net (deflated 78%)
# updating: content/Graphs/2039_15.net (deflated 75%)
# updating: content/Graphs/2334_1.net (deflated 73%)
# updating: content/Graphs/2223_22.net (deflated 74%)
# updating: content/Graphs/114_0.net (deflated 86%)
# updating: content/Graphs/1707_6.net (deflated 71%)
# updating: content/Graphs/451_3.net (deflated 71%)
# updating: content/Graphs/778_21.net (deflated 80%)
# updating: content/Graphs/381_5.net (deflated 76%)
# updating: content/Graphs/85_5.net (deflated 70%)
# updating: content/Graphs/365_6.net (deflated 75%)
# updating: content/Graphs/1172_2.net (deflated 71%)
# updating: content/Graphs/511_2.net (deflated 74%)
# updating: content/Graphs/2223_10.net (deflated 74%)
# updating: content/Graphs/718_23.net (deflated 81%)
# updating: content/Graphs/924_4.net (deflated 75%)
# updating: content/Graphs/404_5.net (deflated 83%)
# updating: content/Graphs/2110_7.net (deflated 78%)
# updating: content/Graphs/884_3.net (deflated 73%)
# updating: content/Graphs/2231_5.net (deflated 85%)
# updating: content/Graphs/1835_15.net (deflated 76%)
# updating: content/Graphs/1852_5.net (deflated 81%)
# updating: content/Graphs/1096_12.net (deflated 74%)
# updating: content/Graphs/480_6.net (deflated 75%)
# updating: content/Graphs/1241_4.net (deflated 77%)
# updating: content/Graphs/1369_1.net (deflated 76%)
# updating: content/Graphs/404_3.net (deflated 77%)
# updating: content/Graphs/293_2.net (deflated 82%)
# updating: content/Graphs/2193_5.net (deflated 76%)
# updating: content/Graphs/1426_4.net (deflated 83%)
# updating: content/Graphs/1287_4.net (deflated 85%)
# updating: content/Graphs/1707_10.net (deflated 71%)
# updating: content/Graphs/1707_12.net (deflated 71%)
# updating: content/Graphs/805_3.net (deflated 75%)
# updating: content/Graphs/2009_1.net (deflated 80%)
# updating: content/Graphs/1707_0.net (deflated 71%)
# updating: content/Graphs/988_3.net (deflated 77%)
# updating: content/Graphs/1426_5.net (deflated 86%)
# updating: content/Graphs/1558_2.net (deflated 83%)
# updating: content/Graphs/1128_8.net (deflated 72%)
# updating: content/Graphs/2208_3.net (deflated 87%)
# updating: content/Graphs/698_7.net (deflated 74%)
# updating: content/Graphs/1260_6.net (deflated 76%)
# updating: content/Graphs/1835_6.net (deflated 75%)
# updating: content/Graphs/1026_0.net (deflated 77%)
# updating: content/Graphs/1241_0.net (deflated 74%)
# updating: content/Graphs/2018_3.net (deflated 84%)
# updating: content/Graphs/365_5.net (deflated 78%)
# updating: content/Graphs/2208_1.net (deflated 76%)
# updating: content/Graphs/1828_1.net (deflated 84%)
# updating: content/Graphs/253_0.net (deflated 81%)
# updating: content/Graphs/98_2.net (deflated 75%)
# updating: content/Graphs/2124_3.net (deflated 76%)
# updating: content/Graphs/1707_5.net (deflated 71%)
# updating: content/Graphs/1917_11.net (deflated 76%)
# updating: content/Graphs/2039_9.net (deflated 76%)
# updating: content/Graphs/1026_1.net (deflated 75%)
# updating: content/Graphs/778_12.net (deflated 76%)
# updating: content/Graphs/1026_4.net (deflated 75%)
# updating: content/Graphs/85_6.net (deflated 81%)
# updating: content/Graphs/98_0.net (deflated 75%)
# updating: content/Graphs/1558_1.net (deflated 79%)
# updating: content/Graphs/77_4.net (deflated 75%)
# updating: content/Graphs/805_0.net (deflated 74%)
# updating: content/Graphs/2124_1.net (deflated 77%)
# updating: content/Graphs/1707_2.net (deflated 71%)
# updating: content/Graphs/1490_0.net (deflated 79%)
# updating: content/Graphs/1228_5.net (deflated 77%)
# updating: content/Graphs/365_2.net (deflated 74%)
# updating: content/Graphs/1241_2.net (deflated 83%)
# updating: content/Graphs/2263_43.net (deflated 76%)
# updating: content/Graphs/2371_4.net (deflated 74%)
# updating: content/Graphs/2263_5.net (deflated 76%)
# updating: content/Graphs/304_0.net (deflated 82%)
# updating: content/Graphs/125_8.net (deflated 78%)
# updating: content/Graphs/1130_0.net (deflated 76%)
# updating: content/Graphs/2305_3.net (deflated 75%)
# updating: content/Graphs/778_7.net (deflated 75%)
# updating: content/Graphs/1852_9.net (deflated 75%)
# updating: content/Graphs/2319_3.net (deflated 79%)
# updating: content/Graphs/2208_4.net (deflated 88%)
# updating: content/Graphs/1260_9.net (deflated 87%)
# updating: content/Graphs/114_4.net (deflated 83%)
# updating: content/Graphs/778_18.net (deflated 75%)
# updating: content/Graphs/1905_8.net (deflated 84%)
# updating: content/Graphs/474_0.net (deflated 75%)
# updating: content/Graphs/1579_11.net (deflated 74%)
# updating: content/Graphs/1289_3.net (deflated 65%)
# updating: content/Graphs/2124_7.net (deflated 82%)
# updating: content/Graphs/2427_2.net (deflated 84%)
# updating: content/Graphs/2263_38.net (deflated 76%)
# updating: content/Graphs/805_1.net (deflated 86%)
# updating: content/Graphs/2371_5.net (deflated 83%)
# updating: content/Graphs/2039_8.net (deflated 76%)
# updating: content/Graphs/884_8.net (deflated 72%)
# updating: content/Graphs/68_3.net (deflated 69%)
# updating: content/Graphs/271_0.net (deflated 86%)
# updating: content/Graphs/361_9.net (deflated 76%)
# updating: content/Graphs/1026_6.net (deflated 74%)
# updating: content/Graphs/1856_5.net (deflated 76%)
# updating: content/Graphs/1835_8.net (deflated 82%)
# updating: content/Graphs/1130_6.net (deflated 79%)
# updating: content/Graphs/1917_8.net (deflated 85%)
# updating: content/Graphs/122_21.net (deflated 75%)
# updating: content/Graphs/2185_1.net (deflated 81%)
# updating: content/Graphs/1551_0.net (deflated 88%)
# updating: content/Graphs/1590_7.net (deflated 83%)
# updating: content/Graphs/1388_3.net (deflated 76%)
# updating: content/Graphs/511_3.net (deflated 73%)
# updating: content/Graphs/1490_5.net (deflated 84%)
# updating: content/Graphs/1287_7.net (deflated 76%)
# updating: content/Graphs/1828_5.net (deflated 76%)
# updating: content/Graphs/1260_0.net (deflated 81%)
# updating: content/Graphs/2263_30.net (deflated 76%)
# updating: content/Graphs/2334_2.net (deflated 77%)
# updating: content/Graphs/474_4.net (deflated 80%)
# updating: content/Graphs/1388_0.net (deflated 76%)
# updating: content/Graphs/679_3.net (deflated 76%)
# updating: content/Graphs/122_16.net (deflated 75%)
# updating: content/Graphs/364_4.net (deflated 71%)
# updating: content/Graphs/2051_6.net (deflated 75%)
# updating: content/Graphs/294_5.net (deflated 76%)
# updating: content/Graphs/1388_9.net (deflated 76%)
# updating: content/Graphs/2185_2.net (deflated 83%)
# updating: content/Graphs/1096_8.net (deflated 72%)
# updating: content/Graphs/93_2.net (deflated 86%)
# updating: content/Graphs/2263_31.net (deflated 82%)
# updating: content/Graphs/2051_3.net (deflated 73%)
# updating: content/Graphs/1369_6.net (deflated 77%)
# updating: content/Graphs/2051_7.net (deflated 81%)
# updating: content/Graphs/2039_11.net (deflated 79%)
# updating: content/Graphs/1856_1.net (deflated 73%)
# updating: content/Graphs/2110_6.net (deflated 84%)
# updating: content/Graphs/2223_13.net (deflated 75%)
# updating: content/Graphs/918_4.net (deflated 81%)
# updating: content/Graphs/1905_3.net (deflated 87%)
# updating: content/Graphs/183_1.net (deflated 75%)
# updating: content/Graphs/2427_4.net (deflated 82%)
# updating: content/Graphs/122_4.net (deflated 75%)
# updating: content/Graphs/2263_18.net (deflated 76%)
# updating: content/Graphs/2263_32.net (deflated 80%)
# updating: content/Graphs/1803_6.net (deflated 84%)
# updating: content/Graphs/480_4.net (deflated 87%)
# updating: content/Graphs/2223_0.net (deflated 74%)
# updating: content/Graphs/1579_8.net (deflated 74%)
# updating: content/Graphs/480_3.net (deflated 79%)
# updating: content/Graphs/2223_9.net (deflated 74%)
# updating: content/Graphs/1943_5.net (deflated 79%)
# updating: content/Graphs/294_2.net (deflated 84%)
# updating: content/Graphs/988_4.net (deflated 76%)
# updating: content/Graphs/1364_2.net (deflated 71%)
# updating: content/Graphs/679_1.net (deflated 75%)
# updating: content/Graphs/1905_1.net (deflated 82%)
# updating: content/Graphs/293_4.net (deflated 77%)
# updating: content/Graphs/451_5.net (deflated 78%)
# updating: content/Graphs/361_6.net (deflated 84%)
# updating: content/Graphs/432_3.net (deflated 69%)
# updating: content/Graphs/1130_5.net (deflated 83%)
# updating: content/Graphs/1128_4.net (deflated 71%)
# updating: content/Graphs/2427_1.net (deflated 82%)
# updating: content/Graphs/2193_1.net (deflated 77%)
# updating: content/Graphs/271_5.net (deflated 73%)
# updating: content/Graphs/718_20.net (deflated 76%)
# updating: content/Graphs/271_4.net (deflated 80%)
# updating: content/Graphs/2051_18.net (deflated 73%)
# updating: content/Graphs/1878_2.net (deflated 73%)
# updating: content/Graphs/1479_1.net (deflated 70%)
# updating: content/Graphs/1558_0.net (deflated 76%)
# updating: content/Graphs/2124_6.net (deflated 84%)
# updating: content/Graphs/1916_4.net (deflated 74%)
# updating: content/Graphs/1549_1.net (deflated 76%)
# updating: content/Graphs/932_4.net (deflated 72%)
# updating: content/Graphs/1818_0.net (deflated 77%)
# updating: content/Graphs/2051_12.net (deflated 82%)
# updating: content/Graphs/778_19.net (deflated 75%)
# updating: content/Graphs/294_3.net (deflated 84%)
# updating: content/Graphs/1426_2.net (deflated 85%)
# updating: content/Graphs/924_2.net (deflated 76%)
# updating: content/Graphs/1026_3.net (deflated 76%)
# updating: content/Graphs/1490_2.net (deflated 85%)
# updating: content/Graphs/1852_2.net (deflated 86%)
# updating: content/Graphs/361_5.net (deflated 81%)
# updating: content/Graphs/480_5.net (deflated 75%)
# updating: content/Graphs/361_2.net (deflated 84%)
# updating: content/Graphs/2305_5.net (deflated 76%)
# updating: content/Graphs/77_5.net (deflated 75%)
# updating: content/Graphs/1479_2.net (deflated 71%)
# updating: content/Graphs/1351_3.net (deflated 70%)
# updating: content/Graphs/1558_6.net (deflated 81%)
# updating: content/Graphs/1388_10.net (deflated 86%)
# updating: content/Graphs/718_18.net (deflated 77%)
# updating: content/Graphs/918_3.net (deflated 76%)
# updating: content/Graphs/2371_2.net (deflated 72%)
# updating: content/Graphs/1351_4.net (deflated 67%)
# updating: content/Graphs/304_3.net (deflated 77%)
# updating: content/Graphs/183_7.net (deflated 77%)
# updating: content/Graphs/2263_40.net (deflated 78%)
# updating: content/Graphs/131_4.net (deflated 61%)
# updating: content/Graphs/1878_6.net (deflated 76%)
# updating: content/Graphs/93_3.net (deflated 74%)
# updating: content/Graphs/361_1.net (deflated 76%)
# updating: content/Graphs/1289_2.net (deflated 71%)
# updating: content/Graphs/314_0.net (deflated 83%)
# updating: content/Graphs/2039_16.net (deflated 79%)
# updating: content/Graphs/1260_5.net (deflated 79%)
# updating: content/Graphs/778_6.net (deflated 78%)
# updating: content/Graphs/2231_2.net (deflated 76%)
# updating: content/Graphs/918_13.net (deflated 78%)
# updating: content/Graphs/679_7.net (deflated 75%)
# updating: content/Graphs/365_4.net (deflated 83%)
# updating: content/Graphs/884_5.net (deflated 74%)
# updating: content/Graphs/1260_11.net (deflated 77%)
# updating: content/Graphs/1916_0.net (deflated 87%)
# updating: content/Graphs/1289_5.net (deflated 68%)
# updating: content/Graphs/1026_5.net (deflated 86%)
# updating: content/Graphs/1745_2.net (deflated 75%)
# updating: content/Graphs/2051_2.net (deflated 74%)
# updating: content/Graphs/2110_2.net (deflated 84%)
# updating: content/Graphs/2263_46.net (deflated 76%)
# updating: content/Graphs/718_10.net (deflated 76%)
# updating: content/Graphs/1388_6.net (deflated 76%)
# updating: content/Graphs/125_9.net (deflated 80%)
# updating: content/Graphs/1260_3.net (deflated 79%)
# updating: content/Graphs/1704_6.net (deflated 72%)
# updating: content/Graphs/698_2.net (deflated 73%)
# updating: content/Graphs/884_4.net (deflated 73%)
# updating: content/Graphs/1579_3.net (deflated 76%)
# updating: content/Graphs/1260_13.net (deflated 76%)
# updating: content/Graphs/947_5.net (deflated 77%)
# updating: content/Graphs/51_3.net (deflated 87%)
# updating: content/Graphs/1128_9.net (deflated 80%)
# updating: content/Graphs/361_7.net (deflated 80%)
# updating: content/Graphs/1886_8.net (deflated 70%)
# updating: content/Graphs/77_1.net (deflated 80%)
# updating: content/Graphs/2051_13.net (deflated 74%)
# updating: content/Graphs/2263_27.net (deflated 84%)
# updating: content/Graphs/1551_4.net (deflated 85%)
# updating: content/Graphs/122_5.net (deflated 75%)
# updating: content/Graphs/2039_10.net (deflated 77%)
# updating: content/Graphs/122_23.net (deflated 75%)
# updating: content/Graphs/432_7.net (deflated 71%)
# updating: content/Graphs/253_5.net (deflated 84%)
# updating: content/Graphs/1172_3.net (deflated 74%)
# updating: content/Graphs/1745_3.net (deflated 80%)
# updating: content/Graphs/432_1.net (deflated 71%)
# updating: content/Graphs/1128_5.net (deflated 71%)
# updating: content/Graphs/1917_4.net (deflated 78%)
# updating: content/Graphs/2193_4.net (deflated 79%)
# updating: content/Graphs/85_2.net (deflated 76%)
# updating: content/Graphs/1809_2.net (deflated 87%)
# updating: content/Graphs/2263_14.net (deflated 81%)
# updating: content/Graphs/122_13.net (deflated 75%)
# updating: content/Graphs/223_6.net (deflated 71%)
# updating: content/Graphs/131_0.net (deflated 55%)
# updating: content/Graphs/2263_22.net (deflated 76%)
# updating: content/Graphs/698_5.net (deflated 76%)
# updating: content/Graphs/1704_5.net (deflated 86%)
# updating: content/Graphs/1549_4.net (deflated 78%)
# updating: content/Graphs/294_6.net (deflated 75%)
# updating: content/Graphs/932_3.net (deflated 72%)
# updating: content/Graphs/2051_9.net (deflated 74%)
# updating: content/Graphs/1590_2.net (deflated 81%)
# updating: content/Graphs/924_3.net (deflated 74%)
# updating: content/Graphs/1138_5.net (deflated 74%)
# updating: content/Graphs/427_4.net (deflated 81%)
# updating: content/Graphs/454_3.net (deflated 80%)
# updating: content/Graphs/1590_6.net (deflated 77%)
# updating: content/Graphs/1388_1.net (deflated 76%)
# updating: content/Graphs/575_3.net (deflated 86%)
# updating: content/Graphs/2018_1.net (deflated 76%)
# updating: content/Graphs/271_10.net (deflated 74%)
# updating: content/Graphs/1852_0.net (deflated 76%)
# updating: content/Graphs/1490_3.net (deflated 78%)
# updating: content/Graphs/1803_0.net (deflated 88%)
# updating: content/Graphs/2427_5.net (deflated 76%)
# updating: content/Graphs/68_4.net (deflated 69%)
# updating: content/Graphs/1704_4.net (deflated 72%)
# updating: content/Graphs/1130_1.net (deflated 74%)
# updating: content/Graphs/2039_6.net (deflated 75%)
# updating: content/Graphs/1818_2.net (deflated 80%)
# updating: content/Graphs/2448_2.net (deflated 78%)
# updating: content/Graphs/1828_12.net (deflated 85%)
# updating: content/Graphs/2263_26.net (deflated 79%)
# updating: content/Graphs/68_0.net (deflated 71%)
# updating: content/Graphs/1584_1.net (deflated 84%)
# updating: content/Graphs/2110_3.net (deflated 82%)
# updating: content/Graphs/918_5.net (deflated 83%)
# updating: content/Graphs/1479_3.net (deflated 71%)
# updating: content/Graphs/718_1.net (deflated 81%)
# updating: content/Graphs/1905_2.net (deflated 86%)
# updating: content/Graphs/1916_6.net (deflated 86%)
# updating: content/Graphs/183_8.net (deflated 79%)
# updating: content/Graphs/1228_7.net (deflated 74%)
# updating: content/Graphs/77_0.net (deflated 77%)
# updating: content/Graphs/122_1.net (deflated 76%)
# updating: content/Graphs/2231_7.net (deflated 86%)
# updating: content/Graphs/1828_11.net (deflated 81%)
# updating: content/Graphs/1569_6.net (deflated 70%)
# updating: content/Graphs/451_6.net (deflated 71%)
# updating: content/Graphs/1228_6.net (deflated 79%)
# updating: content/Graphs/125_2.net (deflated 82%)
# updating: content/Graphs/1364_5.net (deflated 81%)
# updating: content/Graphs/451_4.net (deflated 71%)
# updating: content/Graphs/404_1.net (deflated 76%)
# updating: content/Graphs/805_6.net (deflated 76%)
# updating: content/Graphs/1809_0.net (deflated 73%)
# updating: content/Graphs/1172_1.net (deflated 72%)
# updating: content/Graphs/68_2.net (deflated 71%)
# updating: content/Graphs/1905_7.net (deflated 75%)
# updating: content/Graphs/1707_7.net (deflated 71%)
# updating: content/Graphs/1479_5.net (deflated 76%)
# updating: content/Graphs/1569_5.net (deflated 83%)
# updating: content/Graphs/805_4.net (deflated 76%)
# updating: content/Graphs/93_1.net (deflated 74%)
# updating: content/Graphs/114_5.net (deflated 86%)
# updating: content/Graphs/575_4.net (deflated 80%)
# updating: content/Graphs/1228_17.net (deflated 75%)
# updating: content/Graphs/361_11.net (deflated 77%)
# updating: content/Graphs/2009_6.net (deflated 76%)
# updating: content/Graphs/718_17.net (deflated 76%)
# updating: content/Graphs/2263_16.net (deflated 76%)
# updating: content/Graphs/2124_2.net (deflated 76%)
# updating: content/Graphs/1026_2.net (deflated 72%)
# updating: content/Graphs/1579_12.net (deflated 75%)
# updating: content/Graphs/361_8.net (deflated 88%)
# updating: content/Graphs/1878_7.net (deflated 73%)
# updating: content/Graphs/805_7.net (deflated 87%)
# updating: content/Graphs/223_4.net (deflated 78%)
# updating: content/Graphs/2263_48.net (deflated 76%)
# updating: content/Graphs/1835_7.net (deflated 77%)
# updating: content/Graphs/1905_9.net (deflated 77%)
# updating: content/Graphs/451_0.net (deflated 83%)
# updating: content/Graphs/1096_16.net (deflated 72%)
# updating: content/Graphs/122_19.net (deflated 78%)
# updating: content/Graphs/778_0.net (deflated 76%)
# updating: content/Graphs/679_0.net (deflated 75%)
# updating: content/Graphs/51_1.net (deflated 81%)
# updating: content/Graphs/1917_5.net (deflated 79%)
# updating: content/Graphs/1917_12.net (deflated 77%)
# updating: content/Graphs/1284_1.net (deflated 80%)
# updating: content/Graphs/2263_47.net (deflated 76%)
# updating: content/Graphs/1835_12.net (deflated 76%)
# updating: content/Graphs/1479_6.net (deflated 73%)
# updating: content/Graphs/381_0.net (deflated 88%)
# updating: content/Graphs/2185_6.net (deflated 78%)
# updating: content/Graphs/718_6.net (deflated 80%)
# updating: content/Graphs/454_2.net (deflated 86%)
# updating: content/Graphs/2223_20.net (deflated 74%)
# updating: content/Graphs/1707_1.net (deflated 73%)
# updating: content/Graphs/1128_6.net (deflated 73%)
# updating: content/Graphs/2231_1.net (deflated 78%)
# updating: content/Graphs/1388_4.net (deflated 76%)
# updating: content/Graphs/511_4.net (deflated 71%)
# updating: content/Graphs/2231_12.net (deflated 85%)
# updating: content/Graphs/1704_0.net (deflated 73%)
# updating: content/Graphs/2223_8.net (deflated 77%)
# updating: content/Graphs/2124_5.net (deflated 75%)
# updating: content/Graphs/924_1.net (deflated 77%)
# updating: content/Graphs/85_3.net (deflated 73%)
# updating: content/Graphs/361_3.net (deflated 76%)
# updating: content/Graphs/1878_5.net (deflated 76%)
# updating: content/Graphs/1096_10.net (deflated 72%)
# updating: content/Graphs/1579_9.net (deflated 85%)
# updating: content/Graphs/304_4.net (deflated 88%)
# updating: content/Graphs/918_6.net (deflated 76%)
# updating: content/Graphs/1369_3.net (deflated 72%)
# updating: content/Graphs/381_6.net (deflated 88%)
# updating: content/Graphs/304_1.net (deflated 77%)
# updating: content/Graphs/253_1.net (deflated 86%)
# updating: content/Graphs/1828_9.net (deflated 76%)
# updating: content/Graphs/988_10.net (deflated 76%)
# updating: content/Graphs/122_11.net (deflated 75%)
# updating: content/Graphs/1163_5.net (deflated 74%)
# updating: content/Graphs/1835_3.net (deflated 81%)
# updating: content/Graphs/1905_5.net (deflated 75%)
# updating: content/Graphs/1172_0.net (deflated 86%)
# updating: content/Graphs/679_6.net (deflated 76%)
# updating: content/Graphs/2018_2.net (deflated 78%)
# updating: content/Graphs/2263_19.net (deflated 76%)
# updating: content/Graphs/1096_6.net (deflated 79%)
# updating: content/Graphs/294_8.net (deflated 74%)
# updating: content/Graphs/1569_0.net (deflated 69%)
# updating: content/Graphs/1886_2.net (deflated 76%)
