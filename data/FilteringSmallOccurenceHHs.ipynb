# %%
import pandas as pd

# %%
df = pd.read_csv('150days.csv')

# %%
df.groupby("household_key").filter(lambda x: len(x) > 5)
# Out:
#         household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0                2375  26984851472    1     1004906         1         1.39
# 1                2375  26984851472    1     1033142         1         0.82
# 2                2375  26984851472    1     1036325         1         0.99
# 3                2375  26984851472    1     1082185         1         1.21
# 4                2375  26984851472    1     8160430         1         1.50
# ...               ...          ...  ...         ...       ...          ...
# 350718           1272  28931886027  149     6525354         1         3.49
# 350719           1272  28931886027  149     6588340         1         2.99
# 350720           1272  28931886027  149     8148613         1         3.09
# 350721           1272  28931886027  149     8236004         1         2.29
# 350722           1272  28931886027  149     9874525         2         2.50
#
#         STORE_ID  RETAIL_DISC  TRANS_TIME  WEEK_NO  COUPON_DISC  \
# ...

# %%
df.to_csv('150_days_5min.csv')
